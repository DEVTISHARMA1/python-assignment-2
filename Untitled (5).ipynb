# %% [markdown]
# 1 que
# Flask is a micro web framework for Python, designed to be simple, lightweight, and easy to use. It allows developers to build web applications and APIs quickly and efficiently. Flask is known for its minimalistic and unopinionated design, providing developers with the flexibility to choose their preferred tools and libraries for various tasks.
#  Advantages of Flask Framework:
#  Lightweight and Easy to Learn,Flexible and Extensible,URL Routing,Well-documented

# %% [markdown]
# 2 que
# ![image.png](attachment:475b9e56-8da5-42cf-88ac-8158a8f5932f.png)

# %% [markdown]
# 3 que
# App routing in Flask refers to the process of mapping URL patterns to view functions or handlers. In other words, it determines how incoming HTTP requests are directed to specific functions that handle those requests and generate responses. App routing is a fundamental aspect of building web applications using Flask.

# %% [markdown]
# 4 que
# https://blue-analyst-hlqkx.pwskills.app:5000/welcome
# ![image.png](attachment:ed42af13-acd0-464e-848e-bba617a6e314.png)

# %% [markdown]
# 5 que
# In Flask, the url_for() function is used for URL building. It is a utility function provided by Flask that helps generate URLs for specific view functions or endpoints defined in the application.
